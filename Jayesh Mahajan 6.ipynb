# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayesh-m/Data-Science-assigment/blob/main/Jayesh%20Mahajan%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils import resample
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-5bcbe7a1-9665-4dc3-8773-2510a1d61ed8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bcbe7a1-9665-4dc3-8773-2510a1d61ed8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("apple_quality.csv")

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Scatter plot for the 'Size' attribute
ax.scatter(df.index, df['Size'], color='b', label='Size', s=50)  # s controls marker size

# Adding title and axis labels
ax.set_title('Scatter Plot of Apple Size')
ax.set_xlabel('Index')
ax.set_ylabel('Size')

# Show the legend
ax.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

import pandas as pd

# Assuming df is already defined and contains the 'Size' column

plt.figure(figsize=(12, 8))

# Create a boxplot for the 'Size' attribute
sns.boxplot(y=df['Size'], color='skyblue')

# Adding title and axis labels
plt.title('Boxplot of Apple Size')
plt.ylabel('Size')

# Display the plot
plt.show()

# %%
# Plotting setup
plt.figure(figsize=(12, 8))

# Create a histogram for the 'Size' attribute
plt.hist(df['Size'], bins=20, color='skyblue', edgecolor='black')

# Adding title and axis labels
plt.title('Histogram of Apple Size')
plt.xlabel('Size')
plt.ylabel('Frequency')

# Display the plot
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot for the 'Size' attribute
ax.bar(df.index, df['Size'], color='skyblue', label='Size')

# Adding title and axis labels
ax.set_title('Bar Plot of Apple Size')
ax.set_xlabel('Index')
ax.set_ylabel('Size')

# Show the legend
ax.legend()

# Display the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the line for the 'Size' attribute
ax.plot(df.index, df['Size'], 'b-', label='Size')

# Highlight the most recent data point
latest_index = len(df) - 1
latest_size = df['Size'].iloc[latest_index]
ax.plot(latest_index, latest_size, 'ro', markersize=10, label='Latest Point')

# Adding title and axis labels
ax.set_title('Current State of Apple Size')
ax.set_xlabel('Index')
ax.set_ylabel('Size')

# Show the legend
ax.legend()

# Display the plot
plt.show()

# %%
# Load the data from apple_quality.csv
df = pd.read_csv('apple_quality.csv')

# Ensure 'Size' is numeric
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

# Create bins for a categorical version of the 'Size' attribute
bins = [0, 2, 4, 6, 8, 10]  # Example bins for size
labels = ['Very Small', 'Small', 'Medium', 'Large', 'Very Large']

# Create 'Size_Category' by binning 'Size'
df['Size_Category'] = pd.cut(df['Size'], bins=bins, labels=labels, right=False)

# Plotting setup
plt.figure(figsize=(12, 8))

# Create a line plot with hues for the 'Size_Category'
sns.lineplot(x=df.index, y=df['Size'], hue=df['Size_Category'], palette='tab10')

# Highlight the most recent data point
latest_index = len(df) - 1
latest_size = df['Size'].iloc[latest_index]
latest_category = df['Size_Category'].iloc[latest_index]
plt.plot(latest_index, latest_size, 'ro', markersize=10, label='Latest Point')

# Adding title and axis labels
plt.title('Apple Size with Hues by Size Category')
plt.xlabel('Index')
plt.ylabel('Size')

# Show the legend
plt.legend(title='Category')

# Display the plot
plt.show()
